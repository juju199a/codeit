# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'category': ['skirt', 'sweater', 'coat', 'jeans'],
    'quantity': [10,15,6,11],
    'price': [30000,60000,95000, 3500]
})
df
# Out:
#   category  quantity  price
# 0    skirt        10  30000
# 1  sweater        15  60000
# 2     coat         6  95000
# 3    jeans        11   3500

# %%
df['quantity']
# Out:
# 0    10
# 1    15
# 2     6
# 3    11
# Name: quantity, dtype: int64

# %%
type(df['quantity'])
# Out:
# pandas.core.series.Series

# %%
df['quantity'].mean()
# Out:
# np.float64(10.5)

# %%
df['quantity'].sum()
# Out:
# np.int64(42)

# %%
df['quantity'] * df['price']
# Out:
# 0    300000
# 1    900000
# 2    570000
# 3     38500
# dtype: int64

# %%
import pandas as pd
import numpy as np

# %%
dict_df = pd.DataFrame({
    'category': ['skirt', 'sweater', 'coat', 'jeans'],
    'quantity': [10, 15, 6, 11],                                     
    'price': [30000, 60000, 95000, 35000]
})

# %%
two_dimensional_list = [
    ['skirt', 10, 30000],
    ['sweater', 15, 60000],
    ['coat', 6, 95000],
    ['jeans', 11, 35000]
]
two_dimensional_array = np.array(two_dimensional_list)

list_df = pd.DataFrame(two_dimensional_list)
array_df = pd.DataFrame(two_dimensional_array)

# %%
two_dimensional_array = np.array(two_dimensional_list)

list_df = pd.DataFrame(two_dimensional_list)
array_df = pd.DataFrame(two_dimensional_array)

# %%
import pandas as pd

burger_df = pd.read_csv("data/burger.csv")
burger_df
# Out:
#              product_name  calories  carb  protein  fat  sodium category
# 0                 Whopper       660    49       28   40     1.0  Burgers
# 1          Cheese Whopper       740    50       32   46     1.3  Burgers
# 2          Double Whopper       900    49       48   58     1.0  Burgers
# 3   Double Cheese Whopper       980    50       52   64     1.4  Burgers
# 4          Whopper Junior       310    27       13   18     0.4  Burgers
# 5              Bacon King      1150    49       61   79     2.2  Burgers
# 6     Single Stacker King       700    48       35   42     1.4  Burgers
# 7     Double Stacker King      1050    49       61   68     NaN  Burgers
# 8               Hamburger       240    26       13   10     0.4  Burgers
# 9            Cheeseburger       280    27       15   13     0.6  Burgers
# 10       Double Hamburger       350    26       21   18     0.4  Burgers
# 11    Double Cheeseburger       390    27       23   21     0.6  Burgers
# 12         Crispy Chicken       670    54       23   41     1.1  Chicken
# 13        Chicken Nuggets       170    11        8   11     0.3  Chicken
# 14  Spicy Chicken Nuggets       210    11        8   15     0.6  Chicken

# %%
burger_df_2 = pd.read_csv('data/burger2.csv', header=None, names= ['product_name', 'calories', 'carb', 'protein', 'fat', 'sodium', 'category'])
burger_df_2
# Out:
#              product_name  calories  carb  protein  fat  sodium category
# 0                 Whopper       660    49       28   40     1.0  Burgers
# 1          Cheese Whopper       740    50       32   46     1.3  Burgers
# 2          Double Whopper       900    49       48   58     1.0  Burgers
# 3   Double Cheese Whopper       980    50       52   64     1.4  Burgers
# 4          Whopper Junior       310    27       13   18     0.4  Burgers
# 5              Bacon King      1150    49       61   79     2.2  Burgers
# 6     Single Stacker King       700    48       35   42     1.4  Burgers
# 7     Double Stacker King      1050    49       61   68     NaN  Burgers
# 8               Hamburger       240    26       13   10     0.4  Burgers
# 9            Cheeseburger       280    27       15   13     0.6  Burgers
# 10       Double Hamburger       350    26       21   18     0.4  Burgers
# 11    Double Cheeseburger       390    27       23   21     0.6  Burgers
# 12         Crispy Chicken       670    54       23   41     1.1  Chicken
# 13        Chicken Nuggets       170    11        8   11     0.3  Chicken
# 14  Spicy Chicken Nuggets       210    11        8   15     0.6  Chicken

# %%
import pandas as pd

burger_df = pd.read_csv("data/burger.csv", index_col=0)
burger_df
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Whopper                     660    49       28   40     1.0  Burgers
# Cheese Whopper              740    50       32   46     1.3  Burgers
# Double Whopper              900    49       48   58     1.0  Burgers
# Double Cheese Whopper       980    50       52   64     1.4  Burgers
# Whopper Junior              310    27       13   18     0.4  Burgers
# Bacon King                 1150    49       61   79     2.2  Burgers
# Single Stacker King         700    48       35   42     1.4  Burgers
# Double Stacker King        1050    49       61   68     NaN  Burgers
# Hamburger                   240    26       13   10     0.4  Burgers
# Cheeseburger                280    27       15   13     0.6  Burgers
# Double Hamburger            350    26       21   18     0.4  Burgers
# Double Cheeseburger         390    27       23   21     0.6  Burgers
# Crispy Chicken              670    54       23   41     1.1  Chicken
# Chicken Nuggets             170    11        8   11     0.3  Chicken
# Spicy Chicken Nuggets       210    11        8   15     0.6  Chicken

# %%
import pandas as pd

players_df = pd.read_csv('data/tottenham_2021.csv', index_col='name')
players_df.sort_values(by='matches', ascending=False)
# Out:
#                    matches  minutes  goals  assists
# name
# Pierre Højbjerg         38     3420      2        4
# Hugo Lloris             38     3420      0        0
# Son Heung-Min           37     3114     17       10
# Harry Kane              35     3082     23       14
# Tanguy Ndombele         33     2091      3        2
# Lucas Moura             30     1411      3        4
# Eric Dier               28     2520      0        0
# Sergio Reguilón         27     2244      0        3
# Toby Alderweireld       25     2240      1        0
# Moussa Sissoko          25     1585      0        0
# Érik Lamela             23      717      1        0
# Steven Bergwijn         21     1208      1        3
# Gareth Bale             20      920     11        2
# Ben Davies              20     1346      0        1
# Serge Aurier            19     1605      2        3
# Davinson Sánchez        18     1486      0        0
# Giovani Lo Celso        18      945      1        1
# Matt Doherty            17     1240      0        2
# Dele Alli               15      620      0        1
# Harry Winks             15      861      0        0
# Joe Rodon               12      733      0        0
# Carlos Vinícius          9      308      1        0
# Japhet Tanganga          6      487      0        0
# Dane Scarlett            1        1      0        0

# %%
players_df.describe()
# Out:
#          matches      minutes      goals    assists
# count  24.000000    24.000000  24.000000  24.000000
# mean   22.083333  1566.833333   2.750000   2.083333
# std    10.021354   995.416481   5.855135   3.399702
# min     1.000000     1.000000   0.000000   0.000000
# 25%    16.500000   829.000000   0.000000   0.000000
# 50%    20.500000  1378.500000   0.500000   1.000000
# 75%    28.500000  2241.000000   2.000000   3.000000
# max    38.000000  3420.000000  23.000000  14.000000

# %%
players_df.sort_values(by='minutes', ascending=True)
# Out:
#                    matches  minutes  goals  assists
# name
# Dane Scarlett            1        1      0        0
# Carlos Vinícius          9      308      1        0
# Japhet Tanganga          6      487      0        0
# Dele Alli               15      620      0        1
# Érik Lamela             23      717      1        0
# Joe Rodon               12      733      0        0
# Harry Winks             15      861      0        0
# Gareth Bale             20      920     11        2
# Giovani Lo Celso        18      945      1        1
# Steven Bergwijn         21     1208      1        3
# Matt Doherty            17     1240      0        2
# Ben Davies              20     1346      0        1
# Lucas Moura             30     1411      3        4
# Davinson Sánchez        18     1486      0        0
# Moussa Sissoko          25     1585      0        0
# Serge Aurier            19     1605      2        3
# Tanguy Ndombele         33     2091      3        2
# Toby Alderweireld       25     2240      1        0
# Sergio Reguilón         27     2244      0        3
# Eric Dier               28     2520      0        0
# Harry Kane              35     3082     23       14
# Son Heung-Min           37     3114     17       10
# Pierre Højbjerg         38     3420      2        4
# Hugo Lloris             38     3420      0        0

# %%
# 4번째 Row, 2번째 컬럼
burger_df.iloc[3,1]
# Out:
# np.int64(50)

# %%
# Row 3과 1 컬럼 1과 2
burger_df.iloc[[3,1], [1,2]]
# Out:
#                        carb  protein
# product_name
# Double Cheese Whopper    50       52
# Cheese Whopper           50       32

# %%
burger_df
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Whopper                     660    49       28   40     1.0  Burgers
# Cheese Whopper              740    50       32   46     1.3  Burgers
# Double Whopper              900    49       48   58     1.0  Burgers
# Double Cheese Whopper       980    50       52   64     1.4  Burgers
# Whopper Junior              310    27       13   18     0.4  Burgers
# Bacon King                 1150    49       61   79     2.2  Burgers
# Single Stacker King         700    48       35   42     1.4  Burgers
# Double Stacker King        1050    49       61   68     NaN  Burgers
# Hamburger                   240    26       13   10     0.4  Burgers
# Cheeseburger                280    27       15   13     0.6  Burgers
# Double Hamburger            350    26       21   18     0.4  Burgers
# Double Cheeseburger         390    27       23   21     0.6  Burgers
# Crispy Chicken              670    54       23   41     1.1  Chicken
# Chicken Nuggets             170    11        8   11     0.3  Chicken
# Spicy Chicken Nuggets       210    11        8   15     0.6  Chicken

# %%
# 슬라이싱: Row 1,2,3 (4는 포함안함) Column 0,1,2 (3은 포함안함)
burger_df.iloc[1:4, :3]
# Out:
#                        calories  carb  protein
# product_name
# Cheese Whopper              740    50       32
# Double Whopper              900    49       48
# Double Cheese Whopper       980    50       52

# %%
burger_df.iloc[1:4]
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Cheese Whopper              740    50       32   46     1.3  Burgers
# Double Whopper              900    49       48   58     1.0  Burgers
# Double Cheese Whopper       980    50       52   64     1.4  Burgers

# %%
burger_df.loc['Double Whopper', 'protein']
# Out:
# np.int64(48)

# %%
burger_df.loc[['Whopper', 'Double Whopper'], ['carb', 'protein', 'fat']]
# Out:
#                 carb  protein  fat
# product_name
# Whopper           49       28   40
# Double Whopper    49       48   58

# %%
burger_df.loc['Double Whopper':'Bacon King', :]
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Double Whopper              900    49       48   58     1.0  Burgers
# Double Cheese Whopper       980    50       52   64     1.4  Burgers
# Whopper Junior              310    27       13   18     0.4  Burgers
# Bacon King                 1150    49       61   79     2.2  Burgers

# %%
# loc 이나 iloc을 쓰지 않고 바로 대괄호를 쓸 수 있는 것은
# 슬라이싱 Row에 대해서만 된다.
# 슬라이싱 Column은 오류가 난다.
burger_df['Double Whopper':'Bacon King']
burger_df['calories':'category']
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Double Whopper              900    49       48   58     1.0  Burgers
# Double Cheese Whopper       980    50       52   64     1.4  Burgers
# Whopper Junior              310    27       13   18     0.4  Burgers
# Bacon King                 1150    49       61   79     2.2  Burgers

# %%
# burger_df['calories', 'category'] 오류가 난다. 
# 슬라이싱 컬럼은 절대로 안된다.
burger_df['calories']
# Out:
# product_name
# Whopper                   660
# Cheese Whopper            740
# Double Whopper            900
# Double Cheese Whopper     980
# Whopper Junior            310
# Bacon King               1150
# Single Stacker King       700
# Double Stacker King      1050
# Hamburger                 240
# Cheeseburger              280
# Double Hamburger          350
# Double Cheeseburger       390
# Crispy Chicken            670
# Chicken Nuggets           170
# Spicy Chicken Nuggets     210
# Name: calories, dtype: int64

# %%
burger_df['calories'] < 500
# Out:
# product_name
# Whopper                  False
# Cheese Whopper           False
# Double Whopper           False
# Double Cheese Whopper    False
# Whopper Junior            True
# Bacon King               False
# Single Stacker King      False
# Double Stacker King      False
# Hamburger                 True
# Cheeseburger              True
# Double Hamburger          True
# Double Cheeseburger       True
# Crispy Chicken           False
# Chicken Nuggets           True
# Spicy Chicken Nuggets     True
# Name: calories, dtype: bool

# %%
type(burger_df['calories'] < 500)
# Out:
# pandas.core.series.Series

# %%
burger_df.loc[burger_df['calories'] < 500]
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Whopper Junior              310    27       13   18     0.4  Burgers
# Hamburger                   240    26       13   10     0.4  Burgers
# Cheeseburger                280    27       15   13     0.6  Burgers
# Double Hamburger            350    26       21   18     0.4  Burgers
# Double Cheeseburger         390    27       23   21     0.6  Burgers
# Chicken Nuggets             170    11        8   11     0.3  Chicken
# Spicy Chicken Nuggets       210    11        8   15     0.6  Chicken

# %%
burger_df.loc[burger_df['calories'] < 500, 'protein']
# Out:
# product_name
# Whopper Junior           13
# Hamburger                13
# Cheeseburger             15
# Double Hamburger         21
# Double Cheeseburger      23
# Chicken Nuggets           8
# Spicy Chicken Nuggets     8
# Name: protein, dtype: int64

# %%
burger_df.loc[burger_df['calories'] < 500, 'calories':'protein']
# Out:
#                        calories  carb  protein
# product_name
# Whopper Junior              310    27       13
# Hamburger                   240    26       13
# Cheeseburger                280    27       15
# Double Hamburger            350    26       21
# Double Cheeseburger         390    27       23
# Chicken Nuggets             170    11        8
# Spicy Chicken Nuggets       210    11        8

# %%
mask = burger_df['calories'] < 500
burger_df[mask]
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Whopper Junior              310    27       13   18     0.4  Burgers
# Hamburger                   240    26       13   10     0.4  Burgers
# Cheeseburger                280    27       15   13     0.6  Burgers
# Double Hamburger            350    26       21   18     0.4  Burgers
# Double Cheeseburger         390    27       23   21     0.6  Burgers
# Chicken Nuggets             170    11        8   11     0.3  Chicken
# Spicy Chicken Nuggets       210    11        8   15     0.6  Chicken

# %%
burger_df.loc[mask, 'calories':'fat']
# Out:
#                        calories  carb  protein  fat
# product_name
# Whopper Junior              310    27       13   18
# Hamburger                   240    26       13   10
# Cheeseburger                280    27       15   13
# Double Hamburger            350    26       21   18
# Double Cheeseburger         390    27       23   21
# Chicken Nuggets             170    11        8   11
# Spicy Chicken Nuggets       210    11        8   15

# %%
burger_df.loc['Double Stacker King', 'sodium'] = 1.9

# %%
burger_df
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Whopper                     660    49       28   40     1.0  Burgers
# Cheese Whopper              740    50       32   46     1.3  Burgers
# Double Whopper              900    49       48   58     1.0  Burgers
# Double Cheese Whopper       980    50       52   64     1.4  Burgers
# Whopper Junior              310    27       13   18     0.4  Burgers
# Bacon King                 1150    49       61   79     2.2  Burgers
# Single Stacker King         700    48       35   42     1.4  Burgers
# Double Stacker King        1050    49       61   68     1.9  Burgers
# Hamburger                   240    26       13   10     0.4  Burgers
# Cheeseburger                280    27       15   13     0.6  Burgers
# Double Hamburger            350    26       21   18     0.4  Burgers
# Double Cheeseburger         390    27       23   21     0.6  Burgers
# Crispy Chicken              670    54       23   41     1.1  Chicken
# Chicken Nuggets             170    11        8   11     0.3  Chicken
# Spicy Chicken Nuggets       210    11        8   15     0.6  Chicken

# %%
burger_df.loc['Cheeseburger']
# Out:
# calories        280
# carb             27
# protein          15
# fat              13
# sodium          0.6
# category    Burgers
# Name: Cheeseburger, dtype: object

# %%
burger_df.loc['Cheeseburger'] = [360,24,18,21,0.7,'Burger']

# %%
burger_df
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Whopper                     660    49       28   40     1.0  Burgers
# Cheese Whopper              740    50       32   46     1.3  Burgers
# Double Whopper              900    49       48   58     1.0  Burgers
# Double Cheese Whopper       980    50       52   64     1.4  Burgers
# Whopper Junior              310    27       13   18     0.4  Burgers
# Bacon King                 1150    49       61   79     2.2  Burgers
# Single Stacker King         700    48       35   42     1.4  Burgers
# Double Stacker King        1050    49       61   68     1.9  Burgers
# Hamburger                   240    26       13   10     0.4  Burgers
# Cheeseburger                360    24       18   21     0.7   Burger
# Double Hamburger            350    26       21   18     0.4  Burgers
# Double Cheeseburger         390    27       23   21     0.6  Burgers
# Crispy Chicken              670    54       23   41     1.1  Chicken
# Chicken Nuggets             170    11        8   11     0.3  Chicken
# Spicy Chicken Nuggets       210    11        8   15     0.6  Chicken

# %%
burger_df['sodium']
# Out:
# product_name
# Whopper                  1.0
# Cheese Whopper           1.3
# Double Whopper           1.0
# Double Cheese Whopper    1.4
# Whopper Junior           0.4
# Bacon King               2.2
# Single Stacker King      1.4
# Double Stacker King      1.9
# Hamburger                0.4
# Cheeseburger             0.7
# Double Hamburger         0.4
# Double Cheeseburger      0.6
# Crispy Chicken           1.1
# Chicken Nuggets          0.3
# Spicy Chicken Nuggets    0.6
# Name: sodium, dtype: float64

# %%
burger_df['sodium'] = [1.8]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 burger_df['sodium'] = [1.8]
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
#    4530     ):
#    4531         # broadcast across multiple columns if necessary
#    4532         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5266, in DataFrame._sanitize_column(self, value)
#    5263     return _reindex_for_setitem(value, self.index)
#    5265 if is_list_like(value):
# -> 5266     com.require_length_match(value, self.index)
#    5267 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268 if (
#    5269     isinstance(value, Index)
#    5270     and value.dtype == "object"
#    (...)
#    5273     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5274     # this deprecation
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (1) does not match length of index (15)

# %%
burger_df['sodium'] = 1

# %%
burger_df
# Out:
#                        calories  carb  protein  fat  sodium category
# product_name
# Whopper                     660    49       28   40       1  Burgers
# Cheese Whopper              740    50       32   46       1  Burgers
# Double Whopper              900    49       48   58       1  Burgers
# Double Cheese Whopper       980    50       52   64       1  Burgers
# Whopper Junior              310    27       13   18       1  Burgers
# Bacon King                 1150    49       61   79       1  Burgers
# Single Stacker King         700    48       35   42       1  Burgers
# Double Stacker King        1050    49       61   68       1  Burgers
# Hamburger                   240    26       13   10       1  Burgers
# Cheeseburger                360    24       18   21       1   Burger
# Double Hamburger            350    26       21   18       1  Burgers
# Double Cheeseburger         390    27       23   21       1  Burgers
# Crispy Chicken              670    54       23   41       1  Chicken
# Chicken Nuggets             170    11        8   11       1  Chicken
# Spicy Chicken Nuggets       210    11        8   15       1  Chicken

# %%
burger_df.loc['Tripple Whopper'] = [1130,49,67,75,1.1, 'Burger']

# %%
burger_df['brand'] = 'Burger King'

# %%
burger_df.loc[burger_df['calories'] >= 500]
# Out:
#                        calories  carb  protein  fat  sodium category  \
# product_name
# Whopper                     660    49       28   40     1.0  Burgers
# Cheese Whopper              740    50       32   46     1.0  Burgers
# Double Whopper              900    49       48   58     1.0  Burgers
# Double Cheese Whopper       980    50       52   64     1.0  Burgers
# Bacon King                 1150    49       61   79     1.0  Burgers
# Single Stacker King         700    48       35   42     1.0  Burgers
# Double Stacker King        1050    49       61   68     1.0  Burgers
# Crispy Chicken              670    54       23   41     1.0  Chicken
# Tripple Whopper            1130    49       67   75     1.1   Burger
#
#                              brand
# product_name
# Whopper                Burger King
# Cheese Whopper         Burger King
# Double Whopper         Burger King
# Double Cheese Whopper  Burger King
# Bacon King             Burger King
# Single Stacker King    Burger King
# Double Stacker King    Burger King
# Crispy Chicken         Burger King
# Tripple Whopper        Burger King

# %%
burger_df.loc[burger_df['calories'] >= 500, 'high_calorie'] = True
burger_df.loc[burger_df['calories'] < 500, 'high_calorie'] = False
burger_df
# Out:
#                        calories  carb  protein  fat  sodium category  \
# product_name
# Whopper                     660    49       28   40     1.0  Burgers
# Cheese Whopper              740    50       32   46     1.0  Burgers
# Double Whopper              900    49       48   58     1.0  Burgers
# Double Cheese Whopper       980    50       52   64     1.0  Burgers
# Whopper Junior              310    27       13   18     1.0  Burgers
# Bacon King                 1150    49       61   79     1.0  Burgers
# Single Stacker King         700    48       35   42     1.0  Burgers
# Double Stacker King        1050    49       61   68     1.0  Burgers
# Hamburger                   240    26       13   10     1.0  Burgers
# Cheeseburger                360    24       18   21     1.0   Burger
# Double Hamburger            350    26       21   18     1.0  Burgers
# Double Cheeseburger         390    27       23   21     1.0  Burgers
# Crispy Chicken              670    54       23   41     1.0  Chicken
# Chicken Nuggets             170    11        8   11     1.0  Chicken
# Spicy Chicken Nuggets       210    11        8   15     1.0  Chicken
# Tripple Whopper            1130    49       67   75     1.1   Burger
#
#                              brand high_calorie
# product_name
# Whopper                Burger King         True
# Cheese Whopper         Burger King         True
# Double Whopper         Burger King         True
# Double Cheese Whopper  Burger King         True
# Whopper Junior         Burger King        False
# Bacon King             Burger King         True
# Single Stacker King    Burger King         True
# Double Stacker King    Burger King         True
# Hamburger              Burger King        False
# Cheeseburger           Burger King        False
# Double Hamburger       Burger King        False
# Double Cheeseburger    Burger King        False
# Crispy Chicken         Burger King         True
# Chicken Nuggets        Burger King        False
# Spicy Chicken Nuggets  Burger King        False
# Tripple Whopper        Burger King         True

# %%
import pandas as pd
import matplotlib.pyplot as plt

sales_df = pd.DataFrame({
    'quarter': ['1Q', '2Q', '3Q', '4Q'],
    'revenue': [1360, 2650, 2070, 4150],
    'cost': [1240, 1970, 1750, 2760]
})
sales_df
# Out:
#   quarter  revenue  cost
# 0      1Q     1360  1240
# 1      2Q     2650  1970
# 2      3Q     2070  1750
# 3      4Q     4150  2760

# %%
plt.plot(sales_df['quarter'], sales_df['revenue'])
plt.show()

# %%
# 판다스에서는 조금 간단하게 그래프를 그릴 수 있는 방법이 있습니다.
# 데이터 프레임 뒤에 plot() 이라고 써 주겠습니다.
# plt.show()
sales_df.plot()
plt.show()

# %%
sales_df.plot(x='quarter', y='revenue')
plt.show()

# %%
sales_df.plot(x='quarter', y='revenue', kind='bar')
# Out:
# <Axes: xlabel='quarter'>

# %%
sales_df.plot(y='revenue', kind='pie', labels=['1Q', '2Q', '3Q', '4Q'])
# Out:
# <Axes: ylabel='revenue'>

# %%
burger_df = pd.read_csv('data/')

# %%
burger_df.plot(x='fat', y='calories', kind='scatter')
# Out:
# <Axes: xlabel='fat', ylabel='calories'>

# %%
28*28
# Out:
# 784

# %%
1+1+9+12+18+9+1+1
# Out:
# 52
